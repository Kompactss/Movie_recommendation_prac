# %% [markdown]
# # 3. Collaborative Filtering (협업 필터링 : 사용자 리뷰 기반)

# %%
# !pip install scikit-surprise
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 11.8 MB 16.1 MB/s
# ...
#   Created wheel for scikit-surprise: filename=scikit_surprise-1.1.1-cp37-cp37m-linux_x86_64.whl size=1633733 sha256=d11a451ddc569371821c91a3f4ea021754ca8286bee761ec756019fef44f5921
#   Stored in directory: /root/.cache/pip/wheels/76/44/74/b498c42be47b2406bd27994e16c5188e337c657025ab400c1c
# Successfully built scikit-surprise
# ...

# %%
import surprise
surprise.__version__
# Out:
# '1.1.1'

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
dp = '/content/drive/MyDrive/movie_reco_data/'

# %%
import pandas as pd
from surprise import Reader, Dataset, SVD
from surprise.model_selection import cross_validate

# %%
ratings = pd.read_csv(dp + 'ratings_small.csv')
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1       31     2.5  1260759144
# 1       1     1029     3.0  1260759179
# 2       1     1061     3.0  1260759182
# 3       1     1129     2.0  1260759185
# 4       1     1172     4.0  1260759205

# %%
reader = Reader(rating_scale=(0.5, 5))

# %%
data = Dataset.load_from_df(ratings[['userId', 'movieId', 'rating']], reader=reader)

# %%
data

# %%
svd = SVD(random_state=0)

# %%
cross_validate(svd, data, measures=['RMSE', 'MAE'], cv=5, verbose=True)
# Out:
# Evaluating RMSE, MAE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9008  0.9047  0.8909  0.8908  0.8918  0.8958  0.0058
# MAE (testset)     0.6944  0.6972  0.6864  0.6853  0.6877  0.6902  0.0047
# Fit time          9.12    4.91    4.93    4.90    4.97    5.77    1.68
# Test time         0.25    0.14    0.23    0.13    0.17    0.19    0.05
# {'fit_time': (9.121757745742798,
#   4.911321640014648,
#   4.928206920623779,
#   4.902223587036133,
#   4.974783897399902),
#  'test_mae': array([0.69441851, 0.69718613, 0.68636684, 0.6852821 , 0.68774529]),
#  'test_rmse': array([0.90084387, 0.90467141, 0.8908983 , 0.89082164, 0.89183432]),
#  'test_time': (0.24977922439575195,
#   0.14079618453979492,
#   0.23360443115234375,
#   0.13476920127868652,
#   0.17400789260864258)}

# %%
trainset = data.build_full_trainset()
svd.fit(trainset)

# %%
ratings[ratings['userId'] == 1]
# Out:
#     userId  movieId  rating   timestamp
# 0        1       31     2.5  1260759144
# 1        1     1029     3.0  1260759179
# 2        1     1061     3.0  1260759182
# 3        1     1129     2.0  1260759185
# 4        1     1172     4.0  1260759205
# 5        1     1263     2.0  1260759151
# 6        1     1287     2.0  1260759187
# 7        1     1293     2.0  1260759148
# 8        1     1339     3.5  1260759125
# 9        1     1343     2.0  1260759131
# 10       1     1371     2.5  1260759135
# 11       1     1405     1.0  1260759203
# 12       1     1953     4.0  1260759191
# 13       1     2105     4.0  1260759139
# 14       1     2150     3.0  1260759194
# 15       1     2193     2.0  1260759198
# 16       1     2294     2.0  1260759108
# 17       1     2455     2.5  1260759113
# 18       1     2968     1.0  1260759200
# 19       1     3671     3.0  1260759117

# %%
svd.predict(1, 302, 3)
# Out:
# Prediction(uid=1, iid=302, r_ui=3, est=2.7142061734434044, details={'was_impossible': False})

# %%
svd.predict(1, 1029, 3)  # userId = 1 인 사람이 movieId = 1029 인 영화에 대해서 실제 평가가 3점일 때, 예측 평가 점수
# Out:
# Prediction(uid=1, iid=1029, r_ui=3, est=2.8814455446761933, details={'was_impossible': False})

# %%
svd.predict(100, 1029)
# Out:
# Prediction(uid=100, iid=1029, r_ui=None, est=3.7705476478414846, details={'was_impossible': False})
